# %%
from Extraction.Extractor import Extractor 
import pandas as pd

# %%
ref_tab = pd.read_csv("Data_sets/simple_data/ref.pulse.csv").to_numpy()
sample_tab = pd.read_csv("Data_sets/simple_data/Si.pulse.csv").to_numpy()

extractor = Extractor(ref_tab, sample_tab, thickness=3*1e-3)

extractor.plot_time_domain()

# %%
extractor.fft_signals()

extractor.plot_frequency_domain()

# %%
extractor.calculate_refractive_index(n_0=3.7 + 0.1j)
extractor.plot_refractive_index()

# %%
extractor.get_processed_data()
# Out:
#       frequency  signal_ref     time_ref  signal_sample  time_sample
# 0      0.000000    0.006445  1650.000000       0.000000  1650.000000
# 1      0.016653    0.002210  1650.050000       0.000000  1650.050100
# 2      0.033306    0.000123  1650.100000       0.000000  1650.100200
# 3      0.049958   -0.002270  1650.150000       0.000000  1650.150301
# 4      0.066611   -0.006508  1650.200000       0.000000  1650.200401
# ...         ...         ...          ...            ...          ...
# 1196  19.916736    0.000000  1709.799599      -0.079434  1709.800000
# 1197  19.933389    0.000000  1709.849699       0.049360  1709.850000
# 1198  19.950042    0.000000  1709.899800       0.140247  1709.900000
# 1199  19.966694    0.000000  1709.949900       0.161670  1709.950000
# 1200  19.983347    0.000000  1710.000000       0.132061  1710.000000
#
# [1201 rows x 5 columns]

# %%
extractor.get_fft_data()
# Out:
#       interpolated frequency  amplitude_signal_ref  amplitude_signal_sample  \
# 0                   0.000000             53.374599                15.572690
# 1                   0.004880             59.276619                23.909452
# 2                   0.009760             71.006609                37.244900
# 3                   0.014640             79.658419                47.704227
# 4                   0.019520             80.280936                53.157152
# ...                      ...                   ...                      ...
# 4091               19.963827             71.685773                53.476666
# 4092               19.968707             80.280936                53.157152
# 4093               19.973587             79.658419                47.704227
# 4094               19.978467             71.006609                37.244900
# 4095               19.983347             59.276619                23.909452
#
#       phase_signal_ref  phase_signal_sample
# 0             3.141593             3.141593
# 1             2.118442             1.048684
# 2             1.274017            -0.455079
# 3             0.579982            -1.767323
# 4            -0.013998            -2.994037
# ...                ...                  ...
# 4091      -2192.314229         -5122.928462
# 4092      -2192.817674         -5124.085174
# 4093      -2193.411654         -5125.311888
# 4094      -2194.105689         -5126.624131
# 4095      -2194.950114         -5128.127894
#
# [4096 rows x 5 columns]

# %%
extractor.get_refractive_index_data()
# Out:
#       real_part  imaginary_part
# 0     11.623765    7.490682e-96
# 1      4.940660   -1.041496e+00
# 2      3.903296   -3.462902e-01
# 3      3.574546   -1.430423e-01
# 4      3.433803   -4.376285e-02
# ...         ...             ...
# 4091   3.364752    4.336021e-05
# 4092   3.364694   -5.162303e-05
# 4093   3.364620   -1.316044e-04
# 4094   3.364535   -2.370880e-04
# 4095   3.364482   -4.461029e-04
#
# [4096 rows x 2 columns]
